# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('disney_princess_popularity_dataset_300_rows.csv')
df.head()
# Out:
#   PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0   Pocahontas  Pocahontas's Adventure            1977                   85
# 1        Mulan       Mulan's Adventure            1995                   85
# 2         Raya        Raya's Adventure            1989                  110
# 3         Anna        Anna's Adventure            1940                   78
# 4        Mulan       Mulan's Adventure            1943                  103
#
#    NumberOfSongs HasSoloSong HasDuet HairColor EyeColor OutfitPrimaryColor  \
# 0              4          No     Yes     Brown    Green               Pink
# 1              1         Yes     Yes    Blonde    Brown             Purple
# 2              4          No      No    Blonde    Hazel               Pink
# 3              1          No      No     Brown     Grey              Green
# 4              7          No     Yes     White    Brown              Green
#
#    ... RottenTomatoesScore BoxOfficeMillions AvgScreenTimeMinutes  \
# 0  ...                  88               661                   25
# 1  ...                  91               688                   52
# 2  ...                  76               790                   54
# 3  ...                  70               820                   42
# 4  ...                  86               996                   55
#
#   NumMerchItemsOnAmazon GoogleSearchIndex2024 InstagramFanPages  \
# 0                  2524                    68               298
# 1                  4202                    49               133
# 2                   525                    68               129
# 3                  1951                    73               138
# 4                  3958                    34               155
#
#   TikTokHashtagViewsMillions  \
# 0                        481
# 1                        619
# 2                        230
# 3                        697
# 4                        200
#
#                                         Top3Hashtags IsIconic PopularityScore
# 0  #TeamPocahontas #LovePocahontas #PocahontasFor...      Yes              88
# 1                #TeamMulan #LoveMulan #MulanForever      Yes              78
# 2                   #TeamRaya #LoveRaya #RayaForever       No              53
# 3                   #TeamAnna #LoveAnna #AnnaForever      Yes              84
# 4                #TeamMulan #LoveMulan #MulanForever      Yes              71
#
# [5 rows x 36 columns]

# %%
df.shape
# Out:
# (300, 36)

# %%
df.isna().sum()
# Out:
# PrincessName                  0
# FirstMovieTitle               0
# FirstMovieYear                0
# MovieRuntimeMinutes           0
# NumberOfSongs                 0
# HasSoloSong                   0
# HasDuet                       0
# HairColor                     0
# EyeColor                      0
# OutfitPrimaryColor            0
# OutfitStyleEra                0
# IsRoyalByBirth                0
# HasAnimalSidekick             0
# SidekickType                  0
# HasMagicalPowers              0
# MagicType                     0
# MainSetting                   0
# IsBasedOnRealStory            0
# CulturalOrigin                0
# SpeaksToAnimals               0
# FightsVillainDirectly         0
# RomanticSubplot               0
# MarriedByEnd                  0
# VillainName                   0
# VillainType                   0
# IMDB_Rating                   0
# RottenTomatoesScore           0
# BoxOfficeMillions             0
# AvgScreenTimeMinutes          0
# NumMerchItemsOnAmazon         0
# GoogleSearchIndex2024         0
# InstagramFanPages             0
# TikTokHashtagViewsMillions    0
# Top3Hashtags                  0
# IsIconic                      0
# PopularityScore               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PrincessName                300 non-null    object
#  1   FirstMovieTitle             300 non-null    object
#  2   FirstMovieYear              300 non-null    int64
#  3   MovieRuntimeMinutes         300 non-null    int64
#  4   NumberOfSongs               300 non-null    int64
#  5   HasSoloSong                 300 non-null    object
#  6   HasDuet                     300 non-null    object
#  7   HairColor                   300 non-null    object
#  8   EyeColor                    300 non-null    object
#  9   OutfitPrimaryColor          300 non-null    object
#  10  OutfitStyleEra              300 non-null    object
#  11  IsRoyalByBirth              300 non-null    object
#  12  HasAnimalSidekick           300 non-null    object
#  13  SidekickType                300 non-null    object
#  14  HasMagicalPowers            300 non-null    object
#  15  MagicType                   300 non-null    object
#  16  MainSetting                 300 non-null    object
#  17  IsBasedOnRealStory          300 non-null    object
#  18  CulturalOrigin              300 non-null    object
#  19  SpeaksToAnimals             300 non-null    object
#  20  FightsVillainDirectly       300 non-null    object
#  21  RomanticSubplot             300 non-null    object
#  22  MarriedByEnd                300 non-null    object
#  23  VillainName                 300 non-null    object
#  24  VillainType                 300 non-null    object
#  25  IMDB_Rating                 300 non-null    float64
#  26  RottenTomatoesScore         300 non-null    int64
#  27  BoxOfficeMillions           300 non-null    int64
#  28  AvgScreenTimeMinutes        300 non-null    int64
#  29  NumMerchItemsOnAmazon       300 non-null    int64
#  30  GoogleSearchIndex2024       300 non-null    int64
#  31  InstagramFanPages           300 non-null    int64
#  32  TikTokHashtagViewsMillions  300 non-null    int64
#  33  Top3Hashtags                300 non-null    object
#  34  IsIconic                    300 non-null    object
#  35  PopularityScore             300 non-null    int64
# dtypes: float64(1), int64(11), object(24)
# memory usage: 84.5+ KB

# %%
df.describe()
# Out:
#        FirstMovieYear  MovieRuntimeMinutes  NumberOfSongs  IMDB_Rating  \
# count      300.000000           300.000000     300.000000   300.000000
# mean      1980.243333            90.913333       3.993333     7.466667
# std         24.621227            11.726502       2.149890     0.863311
# min       1937.000000            70.000000       1.000000     6.000000
# 25%       1959.750000            80.000000       2.000000     6.700000
# 50%       1983.000000            91.000000       4.000000     7.400000
# 75%       2000.250000           101.000000       6.000000     8.200000
# max       2021.000000           110.000000       7.000000     9.000000
#
#        RottenTomatoesScore  BoxOfficeMillions  AvgScreenTimeMinutes  \
# count           300.000000         300.000000            300.000000
# mean             80.650000         700.843333             40.616667
# std              10.996237         346.922618             11.575680
# min              60.000000         101.000000             20.000000
# 25%              71.750000         392.000000             31.750000
# 50%              80.000000         709.500000             41.000000
# 75%              90.000000         997.250000             51.000000
# max             100.000000        1300.000000             60.000000
#
#        NumMerchItemsOnAmazon  GoogleSearchIndex2024  InstagramFanPages  \
# count             300.000000             300.000000         300.000000
# mean             2467.270000              61.300000         152.063333
# std              1469.301225              22.393785          83.929214
# min                61.000000              20.000000          10.000000
# 25%              1223.500000              41.750000          75.750000
# 50%              2357.500000              61.000000         148.500000
# 75%              3743.250000              81.000000         227.250000
# max              4998.000000             100.000000         300.000000
#
#        TikTokHashtagViewsMillions  PopularityScore
# count                  300.000000       300.000000
# mean                   506.870000        75.130000
# std                    292.751278        14.293382
# min                     10.000000        50.000000
# 25%                    236.500000        63.000000
# 50%                    524.500000        75.000000
# 75%                    781.250000        87.000000
# max                    999.000000       100.000000

# %% [markdown]
# # EDA

# %%
df.head(3)
# Out:
#   PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0   Pocahontas  Pocahontas's Adventure            1977                   85
# 1        Mulan       Mulan's Adventure            1995                   85
# 2         Raya        Raya's Adventure            1989                  110
#
#    NumberOfSongs HasSoloSong HasDuet HairColor EyeColor OutfitPrimaryColor  \
# 0              4          No     Yes     Brown    Green               Pink
# 1              1         Yes     Yes    Blonde    Brown             Purple
# 2              4          No      No    Blonde    Hazel               Pink
#
#    ... RottenTomatoesScore BoxOfficeMillions AvgScreenTimeMinutes  \
# 0  ...                  88               661                   25
# 1  ...                  91               688                   52
# 2  ...                  76               790                   54
#
#   NumMerchItemsOnAmazon GoogleSearchIndex2024 InstagramFanPages  \
# 0                  2524                    68               298
# 1                  4202                    49               133
# 2                   525                    68               129
#
#   TikTokHashtagViewsMillions  \
# 0                        481
# 1                        619
# 2                        230
#
#                                         Top3Hashtags IsIconic PopularityScore
# 0  #TeamPocahontas #LovePocahontas #PocahontasFor...      Yes              88
# 1                #TeamMulan #LoveMulan #MulanForever      Yes              78
# 2                   #TeamRaya #LoveRaya #RayaForever       No              53
#
# [3 rows x 36 columns]

# %%
df['IsIconic'].value_counts()
# Out:
# Yes    154
# No     146
# Name: IsIconic, dtype: int64

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,6))
sns.countplot(x=df['IsIconic'], palette='winter')
plt.title('Dsitribution of Iconic', fontsize=16)
plt.xlabel('Iconic', fontsize=13)
plt.ylabel('Count', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['PrincessName'], palette='jet_r')
plt.title('Distribution of PrincessName', fontsize=16)
plt.xlabel('PrincessName', fontsize=13)
plt.ylabel('Popularity Score', fontsize=13)
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['PrincessName'], palette='mako', hue=df['HasSoloSong'])
plt.title('Princess Name By HasSolo Song', fontsize=16)
plt.xlabel('PrincessName', fontsize=13)
plt.ylabel('Count', fontsize=13)
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['PrincessName'], palette='jet_r', hue=df['IsIconic'])
plt.title('Princess Name By IsIconic', fontsize=16)
plt.xlabel('PrincessName', fontsize=13)
plt.ylabel('Count', fontsize=13)
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['PrincessName'], palette='Purples', hue=df['NumberOfSongs'], edgecolor='black')
plt.title('Princess Name By Number of Songs', fontsize=16)
plt.xlabel('PrincessName', fontsize=13)
plt.ylabel('Count', fontsize=13)
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['PrincessName'], palette='copper', hue=df['OutfitPrimaryColor'])
plt.title('Princess Name By Outfit Primary Color', fontsize=16)
plt.xlabel('PrincessName', fontsize=13)
plt.ylabel('OutfitPrimaryColor', fontsize=13)
plt.xticks(rotation=50)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x=df['MovieRuntimeMinutes'] , y=df['PopularityScore'], color='orange', marker='o')
plt.title('Movie Runtime Minutes Vs Popularity Score', fontsize=16)
plt.xlabel('MovieRuntimeMinutes', fontsize=13)
plt.ylabel('PopularityScore', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x=df['FirstMovieYear'] , y=df['PopularityScore'], marker='o')
plt.title('First Movie Year Vs Popularity Score', fontsize=16)
plt.xlabel('FirstMovieYear', fontsize=13)
plt.ylabel('PopularityScore', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=df['OutfitPrimaryColor'], y=df['PopularityScore'])
plt.title('Outfit Primary Color Vs Popularity Score', fontsize=16)
plt.xlabel('OutfitPrimaryColor', fontsize=13)
plt.ylabel('PopularityScore', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=df['NumberOfSongs'], y=df['BoxOfficeMillions'], palette='Blues')
plt.title('Number Of Songs Vs BoxOffice Millions', fontsize=16)
plt.xlabel('NumberOfSongs', fontsize=13)
plt.ylabel('BoxOfficeMillions', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='HasSoloSong', y='PopularityScore', data=df)
plt.title('Solo Song Vs Popularity Score', fontsize=15)
plt.xlabel('HasSoloSong', fontsize=13)
plt.ylabel('PopularityScore', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df[['RottenTomatoesScore', 'BoxOfficeMillions']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Between RottenTomatoesScore & BoxOfficeMillions', fontsize=15)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler, OrdinalEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, f1_score, recall_score, classification_report

# %%
df.drop(['Top3Hashtags', 'FirstMovieTitle', 'PrincessName', 'VillainName', 'VillainType', 'SidekickType', 'OutfitStyleEra', 
        'MagicType','MainSetting', 'CulturalOrigin'], axis=1, inplace=True)

# %% [markdown]
# # Encoding Categorical Cols

# %%
categorical_cols = df[['HasSoloSong', 'HasDuet',
       'HairColor', 'EyeColor', 'OutfitPrimaryColor',
       'IsRoyalByBirth', 'HasAnimalSidekick',
       'HasMagicalPowers','IsBasedOnRealStory',
        'SpeaksToAnimals', 'FightsVillainDirectly',
       'RomanticSubplot', 'MarriedByEnd','IsIconic']]

le = LabelEncoder()
for i in categorical_cols:
    df[i]  = le.fit_transform(df[i])

# %% [markdown]
# # Train Test Split

# %%
X = df.drop('IsIconic', axis=1)
y = df['IsIconic']

X_train,X_test, y_train,y_test = train_test_split(X,y , test_size=0.2)
print(f"X_train Shape: {X_train.shape}")
print(f"Y_train Shape: {y_train.shape}")
print(f"X_test Shape: {X_test.shape}")
print(f"y_test Shape: {y_test.shape}")
# Out:
# X_train Shape: (240, 25)
# Y_train Shape: (240,)
# X_test Shape: (60, 25)
# y_test Shape: (60,)

# %% [markdown]
# # Feature Scaling

# %%
scaler = StandardScaler()
scaler.fit(X_train, X_test)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Models Building

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(),
    "SVM": SVC(degree=10),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Decision Tree": DecisionTreeClassifier()
}

# %%
summary = []
for model_names, model in models.items():
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_test_scaled)
    acc = accuracy_score(y_test, preds)
    prec = precision_score(y_test, preds,)
    recal = recall_score(y_test, preds,  average='macro')
    f1 = f1_score(y_test, preds,  average='macro')
    print(f"\n📙 Name: {model_names}")
    print(f"Accuracy: {acc:.2f}")   
    print(f"Precision Score: {prec}")
    print(f"Recall Score: {recal}")
    print(f"F1 Score: {f1}")
    print()
    print(f'{model_names}- Classification Report:')
    cr  = classification_report(y_test,preds)
    print(cr)
    
    summary.append({
        'Models': model_names,
        'Test Accuracy': acc,
        'Test Precision': prec,
        'Test Recall Score': recal,
        'Test F1 Score': f1
        
    })
    summary_df = pd.DataFrame(summary)

# Show all model evaluation metrics in one table
print("\n📝 Summary:")
summary_df
# Out:
# 📙 Name: Logistic Regression
# Accuracy: 0.45
# Precision Score: 0.5135135135135135
# Recall Score: 0.4332579185520362
# F1 Score: 0.43087093992526593
#
# Logistic Regression- Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.35      0.31      0.33        26
#            1       0.51      0.56      0.54        34
#
#     accuracy                           0.45        60
#    macro avg       0.43      0.43      0.43        60
# weighted avg       0.44      0.45      0.44        60
#
#
# 📙 Name: Random Forest
# Accuracy: 0.52
# Precision Score: 0.5714285714285714
# Recall Score: 0.505656108597285
# F1 Score: 0.505541346973572
#
# Random Forest- Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.44      0.42      0.43        26
#            1       0.57      0.59      0.58        34
#
#     accuracy                           0.52        60
#    macro avg       0.51      0.51      0.51        60
# weighted avg       0.51      0.52      0.52        60
#
#
# 📙 Name: Gradient Boosting
# Accuracy: 0.60
# Precision Score: 0.6666666666666666
# Recall Score: 0.6018099547511313
# F1 Score: 0.5982142857142858
#
# Gradient Boosting- Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57        26
#            1       0.67      0.59      0.62        34
#
#     accuracy                           0.60        60
#    macro avg       0.60      0.60      0.60        60
# weighted avg       0.61      0.60      0.60        60
#
#
# 📙 Name: SVM
# Accuracy: 0.48
# Precision Score: 0.5454545454545454
# Recall Score: 0.4762443438914027
# F1 Score: 0.47620388622923115
#
# SVM- Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.41      0.42      0.42        26
#            1       0.55      0.53      0.54        34
#
#     accuracy                           0.48        60
#    macro avg       0.48      0.48      0.48        60
# weighted avg       0.49      0.48      0.48        60
#
#
# 📙 Name: K-Nearest Neighbors
# Accuracy: 0.50
# Precision Score: 0.5666666666666667
# Recall Score: 0.5
# F1 Score: 0.49776785714285715
#
# K-Nearest Neighbors- Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.50      0.46        26
#            1       0.57      0.50      0.53        34
#
#     accuracy                           0.50        60
#    macro avg       0.50      0.50      0.50        60
# weighted avg       0.51      0.50      0.50        60
#
#
# 📙 Name: Naive Bayes
# Accuracy: 0.48
# Precision Score: 0.5428571428571428
# Recall Score: 0.47171945701357465
# F1 Score: 0.4714407502131287
#
# Naive Bayes- Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.40      0.38      0.39        26
#            1       0.54      0.56      0.55        34
#
#     accuracy                           0.48        60
#    macro avg       0.47      0.47      0.47        60
# weighted avg       0.48      0.48      0.48        60
#
#
# 📙 Name: Decision Tree
# Accuracy: 0.58
# Precision Score: 0.6363636363636364
# Recall Score: 0.5780542986425339
# F1 Score: 0.5775837792171219
#
# Decision Tree- Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.52      0.54      0.53        26
#            1       0.64      0.62      0.63        34
#
#     accuracy                           0.58        60
#    macro avg       0.58      0.58      0.58        60
# weighted avg       0.59      0.58      0.58        60
#
#
# 📝 Summary:
#                 Models  Test Accuracy  Test Precision  Test Recall Score  \
# 0  Logistic Regression       0.450000        0.513514           0.433258
# 1        Random Forest       0.516667        0.571429           0.505656
# 2    Gradient Boosting       0.600000        0.666667           0.601810
# 3                  SVM       0.483333        0.545455           0.476244
# 4  K-Nearest Neighbors       0.500000        0.566667           0.500000
# 5          Naive Bayes       0.483333        0.542857           0.471719
# 6        Decision Tree       0.583333        0.636364           0.578054
#
#    Test F1 Score
# 0       0.430871
# 1       0.505541
# 2       0.598214
# 3       0.476204
# 4       0.497768
# 5       0.471441
# 6       0.577584

# %% [markdown]
# # Summary

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=summary_df, x='Models', y='Test Accuracy', palette='winter')
plt.title("Model Accuracy Comparison")
plt.xlabel("Model Name")
plt.ylabel("Accuracy")

plt.xticks(rotation=45)
plt.ylim(0, 1)
plt.show()
